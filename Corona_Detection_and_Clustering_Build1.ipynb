# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhatt/Fall_Fest_iNets/blob/main/Corona_Detection_and_Clustering_Build1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Please find the dataset here:**
#
# https://www.kaggle.com/gunhcolab/fan-fest-20-covid-healthcare-and-economy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import os, gc, cv2, math

import tensorflow as tf
import tensorflow.keras
import tensorflow.keras.backend as K

from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Concatenate, Dense, Conv2D, BatchNormalization, Dropout, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.mixed_precision import experimental as mixed_precision
from skimage import io
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score, roc_curve, f1_score, auc, precision_score, confusion_matrix

print("Tensorflow version: " + tf.__version__)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Tensorflow version: 2.4.0

# %%
# Detecting hardware
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())

except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("replicas: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU  grpc://10.50.182.74:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.50.182.74:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.50.182.74:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# replicas:  8

# %%
# Optimizing Compiler

# %%
MIX = False
XLA = False

if MIX:
    if tpu: 
      policy = tf.keras.mixed_precision.experimental.Policy('mixed_bfloat16')
    else: 
      policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
    mixed_precision.set_policy(policy)
    print('Mixed precision enabled')

if XLA:
    tf.config.optimizer.set_jit(True)
    print('Accelerated Linear Algebra enabled')

# %%
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) 

def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation = cv2.INTER_AREA)

def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    
    rotation = math.pi * rotation / 180. # DEGREES TO RADIANS
    shear = math.pi * shear / 180.
    
    c1 = tf.math.cos(rotation) # ROTATION MATRIX
    s1 = tf.math.sin(rotation)
    one = tf.constant([1], dtype='float32')
    zero = tf.constant([0], dtype='float32')
    rotation_matrix = tf.reshape(tf.concat([c1, s1, zero, -s1, c1, zero, zero, zero, one], axis = 0), [3 ,3] )
        
    c2 = tf.math.cos(shear) # SHEAR MATRIX
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape(tf.concat([one, s2, zero, zero, c2, zero, zero, zero, one], axis = 0), [3, 3])    
    
    zoom_matrix = tf.reshape( tf.concat([one/height_zoom,zero,zero, zero,one/width_zoom,zero, zero,zero,one],axis=0),[3,3]) # ZOOM MATRIX
    
    shift_matrix = tf.reshape( tf.concat([one, zero, height_shift, zero, one, width_shift, zero, zero, one], axis = 0), [3, 3] ) # SHIFT MATRIX
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), K.dot(zoom_matrix, shift_matrix))
    # returns 3x3 transformed matrix which transforms indicies

def transform(image,label):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    DIM = IMAGE_SIZE
    XDIM = DIM%2 #fix for size 331
    
    rot = 15. * tf.random.normal([1],dtype='float32')
    shr = 5. * tf.random.normal([1],dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1],dtype='float32')/10.
    w_zoom = 1.0 + tf.random.normal([1],dtype='float32')/10.
    h_shift = 16. * tf.random.normal([1],dtype='float32') 
    w_shift = 16. * tf.random.normal([1],dtype='float32') 
  
    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image,tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3]),label

def get_training_dataset(dataset, do_aug = True):
    if do_aug: 
        dataset = dataset.map(transform, num_parallel_calls = AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(dataset):
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content/drive/MyDrive/Colab Notebooks/CovidDataset3'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])      
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
train
# Out:
#                                 File  DiseaseID Disease Type
# 0              COVID/Covid (155).png          0        COVID
# 1              COVID/Covid (214).png          0        COVID
# 2              COVID/Covid (209).png          0        COVID
# 3             COVID/Covid (1232).png          0        COVID
# 4             COVID/Covid (1246).png          0        COVID
# ...                              ...        ...          ...
# 2476  non-COVID/Non-Covid (1143).png          1    non-COVID
# 2477  non-COVID/Non-Covid (1042).png          1    non-COVID
# 2478  non-COVID/Non-Covid (1068).png          1    non-COVID
# 2479  non-COVID/Non-Covid (1170).png          1    non-COVID
# 2480  non-COVID/Non-Covid (1146).png          1    non-COVID
#
# [2481 rows x 3 columns]

# %%
IMAGE_SIZE = 64
X = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values), total = len(train)):
    image = read_image(file)
    if image is not None:
        X[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
X /= 255.
y = train['DiseaseID'].values
print(X.shape)
print(y.shape)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2481.0), HTML(value='')))
# (2481, 64, 64, 3)
# (2481,)

# %%
from sklearn.cluster import KMeans

X0 = X[y == 0].reshape(len(X[y == 0]), -1)
X1 = X[y == 1].reshape(len(X[y == 1]), -1)

k = 50
kmeans = KMeans(k)
cluster0 = kmeans.fit_predict(X0)
cluster1 = kmeans.fit_predict(X1)
cluster1 += k
cluster = np.concatenate([cluster0, cluster1])

# %%
np.random.seed(42)

rows = 5 
cols = 5

fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
for i in range(rows):
    clt = np.random.randint(0, 2 * k)
    clt_idx = np.random.choice(np.where(cluster == clt)[0], cols, replace = True)
    X_clt = X[clt_idx]
    for j in range(cols):
        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])
        ax[i, j].set_title([f'Cluster {clt}'])
        ax[i, j].imshow(X_clt[j])

# %%
train_idx, val_idx = next(GroupShuffleSplit(test_size = 0.2, n_splits = 2, random_state = 42).split(X, groups = cluster))

X_train, X_val, Y_train, Y_val = X[train_idx], X[val_idx], y[train_idx], y[val_idx]

BATCH_SIZE = 32 * strategy.num_replicas_in_sync

train_dataset = get_training_dataset(tf.data.Dataset.from_tensor_slices((X_train, Y_train)))
val_dataset = get_validation_dataset(tf.data.Dataset.from_tensor_slices((X_val, Y_val)))

# %%
# EfficientNet models are not applicable on Tensorflow 2.2.0 for TPU
with strategy.scope():

    if not tpu:
        net = tf.keras.applications.EfficientNetB0(include_top = False,
                                                   weights = 'imagenet',
                                                   pooling = None)
    else:
        net = tf.keras.applications.DenseNet121(include_top = False,
                                                weights = 'imagenet',
                                                pooling = None)

    inp = Input(shape = (IMAGE_SIZE, IMAGE_SIZE, 3))
    x = Conv2D(3, (3, 3), padding = 'same')(inp)
    x = net(x)
    x1 = GlobalAveragePooling2D()(x)
    x2 = GlobalMaxPooling2D()(x)
    x = Concatenate()([x1, x2])
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation = 'relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation = 'sigmoid')(x)

    model = Model(inputs = inp, outputs = out)

    metric = tf.keras.metrics.AUC(name = 'auc')
    
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = [metric])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 3)    84          input_2[0][0]
# __________________________________________________________________________________________________
# densenet121 (Functional)        (None, None, None, 1 7037504     conv2d[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           densenet121[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 1024)         0           densenet121[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2048)         0           global_average_pooling2d[0][0]
#                                                                  global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2048)         8192        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            513         dropout_1[0][0]
# ==================================================================================================
# Total params: 8,097,429
# Trainable params: 8,008,661
# Non-trainable params: 88,768
# __________________________________________________________________________________________________

# %%
plot_model(model, 
           show_shapes = True, 
           show_layer_names = True, 
           rankdir = 'TB', 
           expand_nested = False, 
           dpi = 60)

# %%
# Cosine Annealing Learning Rate from 'https://github.com/4uiiurz1/keras-cosine-annealing'

class CosineAnnealingScheduler(Callback):
    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
EPOCHS = 200

annealer = CosineAnnealingScheduler(EPOCHS, 1e-3, 1e-5)

hist = model.fit(train_dataset,
                 steps_per_epoch = X_train.shape[0] // BATCH_SIZE,
                 epochs = EPOCHS,
                 verbose = 1,
                 callbacks = [annealer],
                 validation_data = val_dataset)
# Out:
# Epoch 1/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.0008 - auc: 0.5483WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0068s vs `on_train_batch_end` time: 5.8890s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0068s vs `on_train_batch_end` time: 5.8890s). Check your callbacks.
# 7/7 [==============================] - 88s 3s/step - loss: 0.9833 - auc: 0.5648 - val_loss: 4.9960 - val_auc: 0.5107
# Epoch 2/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.7682 - auc: 0.7535 - val_loss: 13.5304 - val_auc: 0.5000
# Epoch 3/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.6630 - auc: 0.8097 - val_loss: 12.7853 - val_auc: 0.5000
# Epoch 4/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.6740 - auc: 0.8241 - val_loss: 23.5894 - val_auc: 0.5000
# Epoch 5/200
# 7/7 [==============================] - 2s 274ms/step - loss: 0.5210 - auc: 0.8622 - val_loss: 7.7479 - val_auc: 0.5042
# Epoch 6/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.4564 - auc: 0.8871 - val_loss: 5.2136 - val_auc: 0.6044
# Epoch 7/200
# 7/7 [==============================] - 2s 343ms/step - loss: 0.4334 - auc: 0.8990 - val_loss: 2.1573 - val_auc: 0.5315
# Epoch 8/200
# 7/7 [==============================] - 2s 265ms/step - loss: 0.4634 - auc: 0.8805 - val_loss: 5.8040 - val_auc: 0.4336
# Epoch 9/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.3982 - auc: 0.9092 - val_loss: 2.9018 - val_auc: 0.4714
# Epoch 10/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.3820 - auc: 0.9143 - val_loss: 3.0051 - val_auc: 0.4451
# Epoch 11/200
# 7/7 [==============================] - 2s 265ms/step - loss: 0.3506 - auc: 0.9259 - val_loss: 1.3907 - val_auc: 0.5249
# Epoch 12/200
# 7/7 [==============================] - 2s 255ms/step - loss: 0.3208 - auc: 0.9365 - val_loss: 1.0347 - val_auc: 0.5969
# Epoch 13/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.3194 - auc: 0.9394 - val_loss: 0.9291 - val_auc: 0.5937
# Epoch 14/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.3204 - auc: 0.9367 - val_loss: 0.9247 - val_auc: 0.6564
# Epoch 15/200
# 7/7 [==============================] - 2s 265ms/step - loss: 0.3106 - auc: 0.9416 - val_loss: 0.9312 - val_auc: 0.7550
# Epoch 16/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.3236 - auc: 0.9365 - val_loss: 1.6027 - val_auc: 0.7745
# Epoch 17/200
# 7/7 [==============================] - 2s 276ms/step - loss: 0.3177 - auc: 0.9390 - val_loss: 3.3840 - val_auc: 0.7534
# Epoch 18/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.2922 - auc: 0.9506 - val_loss: 1.5855 - val_auc: 0.7974
# Epoch 19/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.2956 - auc: 0.9493 - val_loss: 1.3307 - val_auc: 0.8062
# Epoch 20/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.2863 - auc: 0.9481 - val_loss: 1.3175 - val_auc: 0.8210
# Epoch 21/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.2457 - auc: 0.9636 - val_loss: 1.0917 - val_auc: 0.8318
# Epoch 22/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.2461 - auc: 0.9607 - val_loss: 0.9261 - val_auc: 0.8628
# Epoch 23/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.2404 - auc: 0.9633 - val_loss: 1.1155 - val_auc: 0.8772
# Epoch 24/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.2502 - auc: 0.9628 - val_loss: 1.2766 - val_auc: 0.8844
# Epoch 25/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.2789 - auc: 0.9538 - val_loss: 0.6175 - val_auc: 0.8895
# Epoch 26/200
# 7/7 [==============================] - 2s 268ms/step - loss: 0.2415 - auc: 0.9658 - val_loss: 0.6143 - val_auc: 0.8864
# Epoch 27/200
# 7/7 [==============================] - 2s 371ms/step - loss: 0.2396 - auc: 0.9658 - val_loss: 1.3343 - val_auc: 0.9023
# Epoch 28/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.2210 - auc: 0.9709 - val_loss: 1.0400 - val_auc: 0.9041
# Epoch 29/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.2275 - auc: 0.9674 - val_loss: 1.2332 - val_auc: 0.8910
# Epoch 30/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.2505 - auc: 0.9625 - val_loss: 6.3699 - val_auc: 0.8007
# Epoch 31/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.2348 - auc: 0.9682 - val_loss: 4.5371 - val_auc: 0.8192
# Epoch 32/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.2121 - auc: 0.9747 - val_loss: 1.5737 - val_auc: 0.9024
# Epoch 33/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.2171 - auc: 0.9722 - val_loss: 5.7110 - val_auc: 0.7592
# Epoch 34/200
# 7/7 [==============================] - 2s 271ms/step - loss: 0.1882 - auc: 0.9779 - val_loss: 7.1754 - val_auc: 0.7354
# Epoch 35/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.2148 - auc: 0.9728 - val_loss: 5.6912 - val_auc: 0.7725
# Epoch 36/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1907 - auc: 0.9779 - val_loss: 4.0059 - val_auc: 0.8075
# Epoch 37/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.2078 - auc: 0.9740 - val_loss: 3.9076 - val_auc: 0.8185
# Epoch 38/200
# 7/7 [==============================] - 2s 277ms/step - loss: 0.2194 - auc: 0.9745 - val_loss: 2.2632 - val_auc: 0.8728
# Epoch 39/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.1969 - auc: 0.9783 - val_loss: 1.9796 - val_auc: 0.8892
# Epoch 40/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.1714 - auc: 0.9835 - val_loss: 2.1217 - val_auc: 0.8954
# Epoch 41/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.1772 - auc: 0.9813 - val_loss: 2.0895 - val_auc: 0.8941
# Epoch 42/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1749 - auc: 0.9808 - val_loss: 1.0629 - val_auc: 0.9421
# Epoch 43/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.1620 - auc: 0.9845 - val_loss: 0.9207 - val_auc: 0.9554
# Epoch 44/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1682 - auc: 0.9829 - val_loss: 0.7800 - val_auc: 0.9453
# Epoch 45/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.1483 - auc: 0.9869 - val_loss: 1.2865 - val_auc: 0.9262
# Epoch 46/200
# 7/7 [==============================] - 2s 253ms/step - loss: 0.1718 - auc: 0.9836 - val_loss: 1.5064 - val_auc: 0.9245
# Epoch 47/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.1798 - auc: 0.9818 - val_loss: 2.0658 - val_auc: 0.8891
# Epoch 48/200
# 7/7 [==============================] - 2s 375ms/step - loss: 0.1577 - auc: 0.9845 - val_loss: 2.6139 - val_auc: 0.8375
# Epoch 49/200
# 7/7 [==============================] - 2s 251ms/step - loss: 0.1730 - auc: 0.9841 - val_loss: 1.0095 - val_auc: 0.9056
# Epoch 50/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.1481 - auc: 0.9872 - val_loss: 0.9600 - val_auc: 0.9204
# Epoch 51/200
# 7/7 [==============================] - 2s 251ms/step - loss: 0.1484 - auc: 0.9866 - val_loss: 1.1686 - val_auc: 0.9056
# Epoch 52/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.1235 - auc: 0.9917 - val_loss: 0.9368 - val_auc: 0.9267
# Epoch 53/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1407 - auc: 0.9888 - val_loss: 1.2623 - val_auc: 0.9057
# Epoch 54/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1440 - auc: 0.9893 - val_loss: 1.7169 - val_auc: 0.9384
# Epoch 55/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1405 - auc: 0.9881 - val_loss: 0.6032 - val_auc: 0.9234
# Epoch 56/200
# 7/7 [==============================] - 2s 252ms/step - loss: 0.1373 - auc: 0.9885 - val_loss: 1.1388 - val_auc: 0.9327
# Epoch 57/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.1543 - auc: 0.9842 - val_loss: 1.2910 - val_auc: 0.9244
# Epoch 58/200
# 7/7 [==============================] - 2s 255ms/step - loss: 0.1478 - auc: 0.9874 - val_loss: 0.4314 - val_auc: 0.9061
# Epoch 59/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.1620 - auc: 0.9849 - val_loss: 0.4120 - val_auc: 0.9013
# Epoch 60/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.1448 - auc: 0.9870 - val_loss: 0.4918 - val_auc: 0.8775
# Epoch 61/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.2072 - auc: 0.9823 - val_loss: 0.4917 - val_auc: 0.9415
# Epoch 62/200
# 7/7 [==============================] - 2s 253ms/step - loss: 0.1389 - auc: 0.9904 - val_loss: 0.3395 - val_auc: 0.9240
# Epoch 63/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.1086 - auc: 0.9918 - val_loss: 0.3957 - val_auc: 0.9299
# Epoch 64/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.1126 - auc: 0.9907 - val_loss: 0.4430 - val_auc: 0.9598
# Epoch 65/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0955 - auc: 0.9933 - val_loss: 0.4349 - val_auc: 0.9365
# Epoch 66/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.1278 - auc: 0.9895 - val_loss: 0.5865 - val_auc: 0.9709
# Epoch 67/200
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0973 - auc: 0.9942 - val_loss: 0.6925 - val_auc: 0.9606
# Epoch 68/200
# 7/7 [==============================] - 2s 393ms/step - loss: 0.1195 - auc: 0.9908 - val_loss: 1.6849 - val_auc: 0.9242
# Epoch 69/200
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0890 - auc: 0.9954 - val_loss: 1.9694 - val_auc: 0.8989
# Epoch 70/200
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1089 - auc: 0.9915 - val_loss: 1.5921 - val_auc: 0.9192
# Epoch 71/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.1257 - auc: 0.9900 - val_loss: 0.2873 - val_auc: 0.9489
# Epoch 72/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.1519 - auc: 0.9877 - val_loss: 1.1496 - val_auc: 0.9386
# Epoch 73/200
# 7/7 [==============================] - 2s 265ms/step - loss: 0.1215 - auc: 0.9911 - val_loss: 0.7817 - val_auc: 0.8940
# Epoch 74/200
# 7/7 [==============================] - 2s 270ms/step - loss: 0.1337 - auc: 0.9902 - val_loss: 0.6786 - val_auc: 0.9517
# Epoch 75/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0897 - auc: 0.9952 - val_loss: 0.6382 - val_auc: 0.9651
# Epoch 76/200
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0972 - auc: 0.9945 - val_loss: 0.4481 - val_auc: 0.9708
# Epoch 77/200
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0953 - auc: 0.9944 - val_loss: 1.7356 - val_auc: 0.8969
# Epoch 78/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0890 - auc: 0.9954 - val_loss: 2.5083 - val_auc: 0.8333
# Epoch 79/200
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0896 - auc: 0.9947 - val_loss: 1.0993 - val_auc: 0.9404
# Epoch 80/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0951 - auc: 0.9941 - val_loss: 2.0645 - val_auc: 0.8640
# Epoch 81/200
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0913 - auc: 0.9948 - val_loss: 2.1637 - val_auc: 0.8543
# Epoch 82/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0794 - auc: 0.9963 - val_loss: 1.2745 - val_auc: 0.9193
# Epoch 83/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.1067 - auc: 0.9924 - val_loss: 0.7084 - val_auc: 0.9579
# Epoch 84/200
# 7/7 [==============================] - 2s 264ms/step - loss: 0.1017 - auc: 0.9937 - val_loss: 1.1797 - val_auc: 0.9274
# Epoch 85/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0883 - auc: 0.9947 - val_loss: 0.5669 - val_auc: 0.9578
# Epoch 86/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0859 - auc: 0.9956 - val_loss: 0.8146 - val_auc: 0.9598
# Epoch 87/200
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0820 - auc: 0.9953 - val_loss: 0.6924 - val_auc: 0.9693
# Epoch 88/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0579 - auc: 0.9975 - val_loss: 0.7108 - val_auc: 0.9575
# Epoch 89/200
# 7/7 [==============================] - 2s 393ms/step - loss: 0.0772 - auc: 0.9955 - val_loss: 1.2497 - val_auc: 0.9157
# Epoch 90/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0736 - auc: 0.9956 - val_loss: 0.6687 - val_auc: 0.9542
# Epoch 91/200
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0588 - auc: 0.9979 - val_loss: 0.7286 - val_auc: 0.9538
# Epoch 92/200
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0897 - auc: 0.9930 - val_loss: 1.3057 - val_auc: 0.9136
# Epoch 93/200
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0947 - auc: 0.9947 - val_loss: 0.5708 - val_auc: 0.9576
# Epoch 94/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0945 - auc: 0.9950 - val_loss: 0.5702 - val_auc: 0.9167
# Epoch 95/200
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0821 - auc: 0.9964 - val_loss: 0.5495 - val_auc: 0.8888
# Epoch 96/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0843 - auc: 0.9959 - val_loss: 0.3394 - val_auc: 0.9500
# Epoch 97/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0781 - auc: 0.9959 - val_loss: 0.5753 - val_auc: 0.9436
# Epoch 98/200
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0791 - auc: 0.9963 - val_loss: 0.6180 - val_auc: 0.9452
# Epoch 99/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0597 - auc: 0.9980 - val_loss: 0.5784 - val_auc: 0.9503
# Epoch 100/200
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0672 - auc: 0.9974 - val_loss: 0.6002 - val_auc: 0.9556
# Epoch 101/200
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0632 - auc: 0.9977 - val_loss: 1.0641 - val_auc: 0.9222
# Epoch 102/200
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0509 - auc: 0.9986 - val_loss: 1.5392 - val_auc: 0.9039
# Epoch 103/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0454 - auc: 0.9988 - val_loss: 1.1565 - val_auc: 0.9345
# Epoch 104/200
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0804 - auc: 0.9953 - val_loss: 0.6958 - val_auc: 0.9507
# Epoch 105/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0848 - auc: 0.9958 - val_loss: 0.5130 - val_auc: 0.9600
# Epoch 106/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0822 - auc: 0.9958 - val_loss: 0.4174 - val_auc: 0.9625
# Epoch 107/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0536 - auc: 0.9986 - val_loss: 0.8707 - val_auc: 0.9474
# Epoch 108/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0691 - auc: 0.9945 - val_loss: 1.3807 - val_auc: 0.9173
# Epoch 109/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0664 - auc: 0.9973 - val_loss: 0.9553 - val_auc: 0.9508
# Epoch 110/200
# 7/7 [==============================] - 2s 388ms/step - loss: 0.0550 - auc: 0.9979 - val_loss: 0.5783 - val_auc: 0.9636
# Epoch 111/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0732 - auc: 0.9968 - val_loss: 0.8697 - val_auc: 0.9450
# Epoch 112/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0587 - auc: 0.9978 - val_loss: 0.7682 - val_auc: 0.9563
# Epoch 113/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0518 - auc: 0.9980 - val_loss: 0.8272 - val_auc: 0.9504
# Epoch 114/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0617 - auc: 0.9978 - val_loss: 0.7573 - val_auc: 0.9527
# Epoch 115/200
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0694 - auc: 0.9973 - val_loss: 0.6640 - val_auc: 0.9528
# Epoch 116/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0608 - auc: 0.9977 - val_loss: 0.3368 - val_auc: 0.9851
# Epoch 117/200
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0540 - auc: 0.9981 - val_loss: 0.2655 - val_auc: 0.9770
# Epoch 118/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0536 - auc: 0.9983 - val_loss: 0.5212 - val_auc: 0.9641
# Epoch 119/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0661 - auc: 0.9973 - val_loss: 0.6000 - val_auc: 0.9548
# Epoch 120/200
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0600 - auc: 0.9978 - val_loss: 0.6983 - val_auc: 0.9605
# Epoch 121/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0541 - auc: 0.9984 - val_loss: 0.7682 - val_auc: 0.9473
# Epoch 122/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0596 - auc: 0.9981 - val_loss: 0.9654 - val_auc: 0.9374
# Epoch 123/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0437 - auc: 0.9986 - val_loss: 1.3819 - val_auc: 0.9109
# Epoch 124/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0493 - auc: 0.9985 - val_loss: 1.3582 - val_auc: 0.9145
# Epoch 125/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0446 - auc: 0.9989 - val_loss: 1.1218 - val_auc: 0.9324
# Epoch 126/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0417 - auc: 0.9991 - val_loss: 0.7656 - val_auc: 0.9549
# Epoch 127/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0410 - auc: 0.9986 - val_loss: 0.5710 - val_auc: 0.9682
# Epoch 128/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0563 - auc: 0.9982 - val_loss: 0.7530 - val_auc: 0.9527
# Epoch 129/200
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0430 - auc: 0.9988 - val_loss: 0.6128 - val_auc: 0.9654
# Epoch 130/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0398 - auc: 0.9993 - val_loss: 0.3752 - val_auc: 0.9783
# Epoch 131/200
# 7/7 [==============================] - 2s 385ms/step - loss: 0.0515 - auc: 0.9984 - val_loss: 0.5435 - val_auc: 0.9600
# Epoch 132/200
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0430 - auc: 0.9990 - val_loss: 1.1732 - val_auc: 0.9324
# Epoch 133/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0476 - auc: 0.9982 - val_loss: 1.1577 - val_auc: 0.9281
# Epoch 134/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0381 - auc: 0.9990 - val_loss: 0.9531 - val_auc: 0.9435
# Epoch 135/200
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0358 - auc: 0.9993 - val_loss: 1.1177 - val_auc: 0.9318
# Epoch 136/200
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0389 - auc: 0.9988 - val_loss: 0.8475 - val_auc: 0.9457
# Epoch 137/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0426 - auc: 0.9987 - val_loss: 0.4846 - val_auc: 0.9616
# Epoch 138/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0478 - auc: 0.9968 - val_loss: 0.4204 - val_auc: 0.9704
# Epoch 139/200
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0453 - auc: 0.9975 - val_loss: 0.4333 - val_auc: 0.9716
# Epoch 140/200
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0525 - auc: 0.9984 - val_loss: 0.5000 - val_auc: 0.9696
# Epoch 141/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0439 - auc: 0.9987 - val_loss: 0.6218 - val_auc: 0.9599
# Epoch 142/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0279 - auc: 0.9995 - val_loss: 0.7101 - val_auc: 0.9561
# Epoch 143/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0290 - auc: 0.9996 - val_loss: 0.6614 - val_auc: 0.9580
# Epoch 144/200
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0432 - auc: 0.9979 - val_loss: 0.5428 - val_auc: 0.9649
# Epoch 145/200
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0344 - auc: 0.9990 - val_loss: 0.5366 - val_auc: 0.9596
# Epoch 146/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0327 - auc: 0.9996 - val_loss: 0.5933 - val_auc: 0.9580
# Epoch 147/200
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0236 - auc: 0.9997 - val_loss: 0.6463 - val_auc: 0.9574
# Epoch 148/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0331 - auc: 0.9987 - val_loss: 0.7822 - val_auc: 0.9517
# Epoch 149/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0442 - auc: 0.9992 - val_loss: 0.9134 - val_auc: 0.9463
# Epoch 150/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0366 - auc: 0.9992 - val_loss: 0.8855 - val_auc: 0.9389
# Epoch 151/200
# 7/7 [==============================] - 2s 378ms/step - loss: 0.0311 - auc: 0.9996 - val_loss: 0.8060 - val_auc: 0.9506
# Epoch 152/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0360 - auc: 0.9993 - val_loss: 0.7262 - val_auc: 0.9601
# Epoch 153/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0372 - auc: 0.9987 - val_loss: 0.5950 - val_auc: 0.9655
# Epoch 154/200
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0253 - auc: 0.9996 - val_loss: 0.5281 - val_auc: 0.9676
# Epoch 155/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0262 - auc: 0.9997 - val_loss: 0.5152 - val_auc: 0.9651
# Epoch 156/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0207 - auc: 0.9998 - val_loss: 0.4538 - val_auc: 0.9683
# Epoch 157/200
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0208 - auc: 0.9998 - val_loss: 0.3312 - val_auc: 0.9751
# Epoch 158/200
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0373 - auc: 0.9992 - val_loss: 0.3283 - val_auc: 0.9723
# Epoch 159/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0207 - auc: 0.9998 - val_loss: 0.3473 - val_auc: 0.9656
# Epoch 160/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0412 - auc: 0.9981 - val_loss: 0.3878 - val_auc: 0.9657
# Epoch 161/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0232 - auc: 0.9994 - val_loss: 0.4103 - val_auc: 0.9674
# Epoch 162/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0289 - auc: 0.9995 - val_loss: 0.4528 - val_auc: 0.9679
# Epoch 163/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0333 - auc: 0.9986 - val_loss: 0.4495 - val_auc: 0.9669
# Epoch 164/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0379 - auc: 0.9980 - val_loss: 0.4476 - val_auc: 0.9677
# Epoch 165/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0288 - auc: 0.9991 - val_loss: 0.4638 - val_auc: 0.9681
# Epoch 166/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0351 - auc: 0.9993 - val_loss: 0.5358 - val_auc: 0.9645
# Epoch 167/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0208 - auc: 0.9998 - val_loss: 0.6743 - val_auc: 0.9570
# Epoch 168/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0227 - auc: 0.9997 - val_loss: 0.8063 - val_auc: 0.9469
# Epoch 169/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0267 - auc: 0.9996 - val_loss: 0.7671 - val_auc: 0.9511
# Epoch 170/200
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0406 - auc: 0.9990 - val_loss: 0.7034 - val_auc: 0.9561
# Epoch 171/200
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0261 - auc: 0.9997 - val_loss: 0.6936 - val_auc: 0.9589
# Epoch 172/200
# 7/7 [==============================] - 2s 395ms/step - loss: 0.0267 - auc: 0.9995 - val_loss: 0.7505 - val_auc: 0.9556
# Epoch 173/200
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0324 - auc: 0.9986 - val_loss: 0.7885 - val_auc: 0.9551
# Epoch 174/200
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0354 - auc: 0.9991 - val_loss: 0.7280 - val_auc: 0.9609
# Epoch 175/200
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0280 - auc: 0.9995 - val_loss: 0.7125 - val_auc: 0.9605
# Epoch 176/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0196 - auc: 0.9998 - val_loss: 0.7133 - val_auc: 0.9578
# Epoch 177/200
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0323 - auc: 0.9988 - val_loss: 0.6929 - val_auc: 0.9604
# Epoch 178/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0243 - auc: 0.9995 - val_loss: 0.7169 - val_auc: 0.9575
# Epoch 179/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0308 - auc: 0.9993 - val_loss: 0.7462 - val_auc: 0.9575
# Epoch 180/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0323 - auc: 0.9987 - val_loss: 0.7252 - val_auc: 0.9592
# Epoch 181/200
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0294 - auc: 0.9993 - val_loss: 0.7329 - val_auc: 0.9578
# Epoch 182/200
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0236 - auc: 0.9995 - val_loss: 0.7217 - val_auc: 0.9577
# Epoch 183/200
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0293 - auc: 0.9992 - val_loss: 0.7247 - val_auc: 0.9574
# Epoch 184/200
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0263 - auc: 0.9997 - val_loss: 0.7039 - val_auc: 0.9564
# Epoch 185/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0394 - auc: 0.9991 - val_loss: 0.7078 - val_auc: 0.9550
# Epoch 186/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0187 - auc: 0.9998 - val_loss: 0.7208 - val_auc: 0.9537
# Epoch 187/200
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0174 - auc: 0.9998 - val_loss: 0.7043 - val_auc: 0.9590
# Epoch 188/200
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0194 - auc: 0.9997 - val_loss: 0.7205 - val_auc: 0.9562
# Epoch 189/200
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0300 - auc: 0.9984 - val_loss: 0.7164 - val_auc: 0.9535
# Epoch 190/200
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0361 - auc: 0.9992 - val_loss: 0.7051 - val_auc: 0.9555
# Epoch 191/200
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0176 - auc: 0.9999 - val_loss: 0.6980 - val_auc: 0.9555
# Epoch 192/200
# 7/7 [==============================] - 2s 384ms/step - loss: 0.0228 - auc: 0.9997 - val_loss: 0.6860 - val_auc: 0.9579
# Epoch 193/200
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0330 - auc: 0.9994 - val_loss: 0.6408 - val_auc: 0.9615
# Epoch 194/200
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0188 - auc: 0.9998 - val_loss: 0.6307 - val_auc: 0.9609
# Epoch 195/200
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0189 - auc: 0.9998 - val_loss: 0.6364 - val_auc: 0.9612
# Epoch 196/200
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0428 - auc: 0.9986 - val_loss: 0.6219 - val_auc: 0.9612
# Epoch 197/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0251 - auc: 0.9997 - val_loss: 0.6640 - val_auc: 0.9604
# Epoch 198/200
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0279 - auc: 0.9995 - val_loss: 0.6703 - val_auc: 0.9594
# Epoch 199/200
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0269 - auc: 0.9995 - val_loss: 0.6863 - val_auc: 0.9568
# Epoch 200/200
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0315 - auc: 0.9981 - val_loss: 0.6807 - val_auc: 0.9580

# %%
# AUC score is better than accuracy if the classes are imbalanced
print('Best Validation AUC:\t', round(max(hist.history['val_auc']), 2))

auc = hist.history['auc']
val_auc = hist.history['val_auc']
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs = range(len(auc))

plt.figure(figsize = (7, 5))
plt.title('Training and Validation AUC')
plt.plot(epochs, auc, 'r', label = 'Train')
plt.plot(epochs, val_auc, 'b', label = 'Val')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend(loc = 0)
plt.show()
# Out:
# Best Validation AUC:	 0.99

# %%
pred_proba = model.predict(X_val)
auc_score = roc_auc_score(Y_val, pred_proba)
fpr, tpr, th = roc_curve(Y_val, pred_proba)
print('AUC Score:\t', round(auc_score, 2))
# Out:
# AUC Score:	 0.98

# %%
plt.figure(figsize = (7, 5))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'r')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.legend(loc = 4)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
def threshold_optimisation(y_true, y_pred, thresholds):
    best_th = thresholds[0]
    best_acc = accuracy_score(y_true, np.where(y_pred > thresholds[0], 1, 0))
    for th in thresholds[1:]:
        acc = accuracy_score(y_true, np.where(y_pred > th, 1, 0))
        if acc > best_acc:
            best_th = th
            best_acc = acc
    return best_acc, best_th
best_acc, best_th = threshold_optimisation(Y_val, pred_proba, th)
print('Best Accuracy:\t', round(best_acc, 2))
print('Best Threshold:\t', best_th)
# Out:
# Best Accuracy:	 0.94
# Best Threshold:	 0.996783

# %%
from tensorflow.keras.preprocessing import image

img = image.load_img('/content/drive/MyDrive/Colab Notebooks/CovidDataset3/COVID/Covid (1010).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/drive/MyDrive/Colab Notebooks/CovidDataset3/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=int(np.round(a))
        
print('Prediction:',disease_class[ind])
# Out:
# [0.]
# Prediction: Covid-19

# %%
img = image.load_img('/content/drive/MyDrive/Colab Notebooks/CovidDataset3/non-COVID/Non-Covid (1001).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/drive/MyDrive/Colab Notebooks/CovidDataset3/non-COVID/Non-Covid (1001).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=int(np.round(a))
        
print('Prediction:',disease_class[ind])
# Out:
# [0.99690473]
# Prediction: Non Covid-19

# %%
Y_pred = model.predict(X_val)
y_pred = []
import seaborn as sns
for i in Y_pred:
  y_pred.append(int(np.round(float(i))))

b = np.array(y_pred)

Y_true = np.argmax(Y_val)

cm = confusion_matrix(Y_val, b)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
ture_negitive, false_Positive, false_negitive, true_Positive = cm.ravel()
Specificity = ture_negitive/(ture_negitive+false_Positive)
Sensitivity = true_Positive/(true_Positive+false_negitive)


print('f1 score =  %.3f'%f1_score(Y_val, np.round(Y_pred)))
print('Precision =  %.3f'%precision_score(Y_val, np.round(Y_pred)))
print('Specificity =  %.3f'%Specificity)
print('Sensitivity =  %.3f'%Sensitivity)
# Out:
# f1 score =  0.833
# Precision =  0.713
# Specificity =  0.783
# Sensitivity =  1.000
